# %% [markdown]
# # Conclusions
# * **Capomulin and Ramicane showed strong results well outside the boundaries of standard error in all three dimensions studied** over the 45-day study:
#   * Tumor Volume
#   * Metastatic Sites
#   * Survival Rate
# * Other drugs showed weak positive results:
#   * Infubinol and Stelasyn had a lower number of Metastatic Sites than the mean
#   * Zoniferol slightly bettered the mean Survival Rate
# * The unmistakable 60-percentage-point reduction in Tumor Volumes produced by Capomulin and Ramicane compared to all other protocols (including the placebo) **strongly suggest a causal relationship between (1) administering Capomulin and Ramicane and (2) reducing the size, and limiting the number of sites, of squamous cell carcinomas.**

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
strClin = "data/clinicaltrial_data.csv"
strMouse = "data/mouse_drug_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
dfClin = pd.read_csv(strClin)
dfMouse = pd.read_csv(strMouse)

# Combine the data into a single dataset
dfMrg = pd.merge(dfClin, dfMouse, on='Mouse ID')

# Display the data table for preview
dfMrg.head(10)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin
# 5     b128         25           43.262145                 1  Capomulin
# 6     b128         30           40.605335                 1  Capomulin
# 7     b128         35           37.967644                 1  Capomulin
# 8     b128         40           38.379726                 2  Capomulin
# 9     b128         45           38.982878                 2  Capomulin

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
grpByDT = dfMrg.groupby(['Drug','Timepoint'])

# Convert to DataFrame
dfTVMean = grpByDT.mean()
dfTVMean = dfTVMean['Tumor Volume (mm3)']
dfTVMean = dfTVMean.reset_index()

# Preview DataFrame
dfTVMean.head(20)
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# 5   Capomulin         25           39.939528
# 6   Capomulin         30           38.769339
# 7   Capomulin         35           37.816839
# 8   Capomulin         40           36.958001
# 9   Capomulin         45           36.236114
# 10   Ceftamin          0           45.000000
# 11   Ceftamin          5           46.503051
# 12   Ceftamin         10           48.285125
# 13   Ceftamin         15           50.094055
# 14   Ceftamin         20           52.157049
# 15   Ceftamin         25           54.287674
# 16   Ceftamin         30           56.769517
# 17   Ceftamin         35           58.827548
# 18   Ceftamin         40           61.467895
# 19   Ceftamin         45           64.132421

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
dfTVSErr = grpByDT.sem()
dfTVSErr = dfTVSErr['Tumor Volume (mm3)']
dfTVSErr = dfTVSErr.reset_index()

# Preview DataFrame
dfTVSErr.head(20)
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# 5   Capomulin         25            0.881642
# 6   Capomulin         30            0.934460
# 7   Capomulin         35            1.052241
# 8   Capomulin         40            1.223608
# 9   Capomulin         45            1.223977
# 10   Ceftamin          0            0.000000
# 11   Ceftamin          5            0.164505
# 12   Ceftamin         10            0.236144
# 13   Ceftamin         15            0.332053
# 14   Ceftamin         20            0.359482
# 15   Ceftamin         25            0.439356
# 16   Ceftamin         30            0.490620
# 17   Ceftamin         35            0.692248
# 18   Ceftamin         40            0.708505
# 19   Ceftamin         45            0.902358

# %%
# Minor Data Munging to Re-Format the Data Frames
dfTVMean = pd.crosstab(dfTVMean['Timepoint'], dfTVMean['Drug'], \
                       values=dfTVMean['Tumor Volume (mm3)'], aggfunc='mean')

# Preview that Reformatting worked
dfTVMean
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames
dfTVSErr = pd.crosstab(dfTVSErr['Timepoint'], dfTVSErr['Drug'], \
                       values=dfTVSErr['Tumor Volume (mm3)'], aggfunc='mean')

# Preview that Reformatting worked
dfTVSErr
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# compute Max Timepoint
intMaxTP = max(dfTVMean.index)
intMaxTP
# Out:
# 45

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots()
for col in dfTVMean.columns:
    # use a different style for positive slopes and negative slopes
    if dfTVMean[col][0] > dfTVMean[col][intMaxTP]:
        ax.errorbar(dfTVMean.index, dfTVMean[col], dfTVSErr[col], \
                    fmt="s", linestyle='solid', linewidth=4, label=col, \
                    markersize=8)
        plt.annotate(s=col, xy=(intMaxTP, dfTVMean[col].loc[intMaxTP]))
    else:
        ax.errorbar(dfTVMean.index, dfTVMean[col], dfTVSErr[col], \
                    fmt="o", linestyle='dotted', label=col)
        
ax.set_title('Tumor Volume', fontsize=18)
ax.set_xlabel("Time (Days)", fontsize=12)
ax.set_ylabel("Tumor Volume (mm³)", fontsize=12)
ax.set_xlim(-1, 50)       # set subjectively
ax.set_ylim(30, 80)       # set subjectively
fig.legend(loc=(.75, .3)) # set subjectively
    
fig = plt.gcf()
fig.set_size_inches(12, 10)
# Save the Figure
plt.savefig("Pymaceuticals01-Tumor Volume.png")
# Show the Figure
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
dfMSMean = grpByDT.mean()

# Convert to DataFrame
dfMSMean = dfMSMean['Metastatic Sites']
dfMSMean = dfMSMean.reset_index()

# Preview DataFrame
dfMSMean.head(20)
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# 5   Capomulin         25          0.818182
# 6   Capomulin         30          1.090909
# 7   Capomulin         35          1.181818
# 8   Capomulin         40          1.380952
# 9   Capomulin         45          1.476190
# 10   Ceftamin          0          0.000000
# 11   Ceftamin          5          0.380952
# 12   Ceftamin         10          0.600000
# 13   Ceftamin         15          0.789474
# 14   Ceftamin         20          1.111111
# 15   Ceftamin         25          1.500000
# 16   Ceftamin         30          1.937500
# 17   Ceftamin         35          2.071429
# 18   Ceftamin         40          2.357143
# 19   Ceftamin         45          2.692308

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
dfMSSErr = grpByDT.sem()

# Convert to DataFrame
dfMSSErr = dfMSSErr['Metastatic Sites']
dfMSSErr = dfMSSErr.reset_index()

# Preview DataFrame
dfMSSErr.head(20)
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# 5   Capomulin         25          0.181818
# 6   Capomulin         30          0.172944
# 7   Capomulin         35          0.169496
# 8   Capomulin         40          0.175610
# 9   Capomulin         45          0.202591
# 10   Ceftamin          0          0.000000
# 11   Ceftamin          5          0.108588
# 12   Ceftamin         10          0.152177
# 13   Ceftamin         15          0.180625
# 14   Ceftamin         20          0.241034
# 15   Ceftamin         25          0.258831
# 16   Ceftamin         30          0.249479
# 17   Ceftamin         35          0.266526
# 18   Ceftamin         40          0.289128
# 19   Ceftamin         45          0.286101

# %%
# Minor Data Munging to Re-Format the Data Frames
dfMSMean = pd.crosstab(dfMSMean['Timepoint'], dfMSMean['Drug'], \
                       values=dfMSMean['Metastatic Sites'], aggfunc='mean')

# Preview that Reformatting worked
dfMSMean
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames
dfMSSErr = pd.crosstab(dfMSSErr['Timepoint'], dfMSSErr['Drug'], \
                       values=dfMSSErr['Metastatic Sites'], aggfunc='mean')

# Preview that Reformatting worked
dfMSSErr
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# compute the Mean Metastatic Sites at the Max Timepoint
fltMeanMS = dfMSMean.loc[intMaxTP].mean()
fltMeanMS
# Out:
# 2.4074564324564327

# %%
# Generate the Plot (with Error Bars)
fig, ax = plt.subplots()
for col in dfMSMean.columns:
    # use a different style for below-mean and above-mean series
    if dfMSMean[col][intMaxTP] < fltMeanMS:
        ax.errorbar(dfMSMean.index, dfMSMean[col], dfMSSErr[col], \
                    fmt="s", linestyle='solid', linewidth=4, label=col, \
                    markersize=8)
        plt.annotate(s=col, xy=(intMaxTP, dfMSMean[col].loc[intMaxTP]))
    else:
        ax.errorbar(dfMSMean.index, dfMSMean[col], dfMSSErr[col], \
                    fmt="o", linestyle='dotted', label=col)
        
ax.set_title('Metastatic Sites', fontsize=18)
ax.set_xlabel('Time (Days)', fontsize=12)
ax.set_ylabel('Metastatic Sites', fontsize=12)
ax.set_xlim(-1, 50)        # set subjectively
fig.legend(loc=(.45, .65)) # set subjectively
    
fig = plt.gcf()
fig.set_size_inches(12, 10)
# Save the Figure
plt.savefig("Pymaceuticals02-Metastatic Sites.png")

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
dfMCount = grpByDT.nunique()

# Convert to DataFrame
dfMCount = dfMCount['Mouse ID']
dfMCount = dfMCount.reset_index()
dfMCount = dfMCount.rename(columns={'Mouse ID':'Mouse Count'})

# Preview DataFrame
dfMCount.head(20)
# Out:
#          Drug  Timepoint  Mouse Count
# 0   Capomulin          0           25
# 1   Capomulin          5           25
# 2   Capomulin         10           25
# 3   Capomulin         15           24
# 4   Capomulin         20           23
# 5   Capomulin         25           22
# 6   Capomulin         30           22
# 7   Capomulin         35           22
# 8   Capomulin         40           21
# 9   Capomulin         45           21
# 10   Ceftamin          0           25
# 11   Ceftamin          5           21
# 12   Ceftamin         10           20
# 13   Ceftamin         15           19
# 14   Ceftamin         20           18
# 15   Ceftamin         25           18
# 16   Ceftamin         30           16
# 17   Ceftamin         35           14
# 18   Ceftamin         40           14
# 19   Ceftamin         45           13

# %%
# Minor Data Munging to Re-Format the Data Frames
dfMCount = pd.crosstab(dfMCount['Timepoint'], dfMCount['Drug'], \
                       values=dfMCount['Mouse Count'], aggfunc='mean')

# Preview that Reformatting worked
dfMCount
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                25        25        25         25
# 5                24        25        24         24
# ...

# %%
# compute the Max Mouse Count at Timepoint 0
fltMaxM = float(dfMCount.loc[0].max())
fltMaxM
# Out:
# 25.0

# %%
# compute the Mean Mouse Count at the Max Timepoint
fltMeanM = dfMCount.loc[intMaxTP].mean()
fltMeanM
# Out:
# 13.0

# %%
# Generate the Plot (Accounting for percentages)
fig, ax = plt.subplots()
for col in dfMCount.columns:
    # use a different style for below-mean and above-mean series
    if dfMCount[col][intMaxTP] > fltMeanM:
        ax.errorbar(dfMCount.index, dfMCount[col] / fltMaxM, 
                    fmt="s", linestyle='solid', linewidth=4, \
                    label=col, markersize=8)
        plt.annotate(s=col, xy=(intMaxTP, \
                                dfMCount[col].loc[intMaxTP] / fltMaxM))
    else:
        ax.errorbar(dfMCount.index, dfMCount[col] / fltMaxM, \
                    fmt="o", linestyle='dotted', label=col)
ax.set_title('Survival Rate', fontsize=18)
ax.set_xlabel('Time (Days)', fontsize=12)
ax.set_ylabel('Survival Rate', fontsize=12)
ax.set_xlim(-1, 50)        # set subjectively
fig.legend(loc=(.45, .15)) # set subjectively
lstYLbl = [format(lbl, '0.0%') for lbl in ax.get_yticks()]
ax.set_yticklabels(lstYLbl)
    
fig = plt.gcf()
fig.set_size_inches(12, 10)
# Save the Figure
plt.savefig("Pymaceuticals03-Survival Rate.png")

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
lstDrug = []
lstTVPctChg = []
for col in dfTVMean.columns:
    lstDrug.append(col)
    lstTVPctChg.append((dfTVMean[col][intMaxTP] - dfTVMean[col][0]) / dfTVMean[col][0])
# Display the data to confirm
lstTVPctChg
# Out:
# [-0.19475302667894157,
#  0.42516491855897415,
#  0.46123471727851845,
#  0.5702879468660604,
#  0.539233471347692,
#  0.5129796048315153,
#  0.47241174863206337,
#  -0.22320900462766657,
#  0.5208513428789899,
#  0.4657975086509522]

# %%
# Generate the Plot (Accounting for percentages)
fig, ax = plt.subplots()
for index in range(len(lstTVPctChg)):
    # use a different style for below-zero and above-zero values
    if lstTVPctChg[index] > 0:
        ax.bar(index, lstTVPctChg[index], color='red')
    else:
        ax.bar(index, lstTVPctChg[index], color='green')
ax.set_title('Percent Change in Tumor Volume', fontsize=18)
ax.set_xlabel('Drug', fontsize=12)
ax.set_ylabel('Percent Change in Tumor Volume', fontsize=12)
plt.xticks(ticks=np.arange(0,10), rotation=45, ha='right')
lstXLbl = [lstDrug[index] + '\n(' + format(lstTVPctChg[index], "0.0%") + \
           ')' for index in range(len(lstTVPctChg))]
ax.set_xticklabels(lstXLbl)
lstYLbl = [format(lbl, '0.0%') for lbl in ax.get_yticks()]
ax.set_yticklabels(lstYLbl)
    
fig = plt.gcf()
fig.set_size_inches(12, 10)
fig.show()

# Save the Figure
plt.savefig("Pymaceuticals04-Percent Change.png")
